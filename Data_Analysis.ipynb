# %%
import script
from sklearn import linear_model
import requests
df = script.df
data_frame = script.data_frame

# %%
# Count the number of fake and real news
df_1 = df.groupby(['label'])['label'].count()

x1 = ['Fake', 'Real']
y1 = []
y1.append(df_1[0])
y1.append(df_1[1])

c = ['red', 'blue']

# %%
# Make a bar graph for total number of fake and real news
plt.bar(x1, y1, color=c)
plt.title("Total Number of Fake and Real News")
plt.xlabel("Fake/Real")
plt.ylabel("Number of fakes and reals")
plt.show()

# %%
#plotting bar graph with values counting keywords 
#counters for y axis values
counter_FTrump = 0
counter_TTrump = 0
                 
counter_FClinton = 0
counter_TClinton = 0

counter_FRepublican = 0
counter_TRepublican = 0

counter_FDemocrat = 0
counter_TDemocrat = 0

counter_FGOP = 0
counter_TGOP = 0

counter_FObama = 0
counter_TObama = 0

# %%
for i in range(6335):
    title = data_frame.loc[i,'title']
    label = data_frame.loc[i,'label'] 
    
    if 'Trump' in title and 'FAKE' in label:
        counter_FTrump += 1

    if 'Trump' in title and 'REAL' in label :
        counter_TTrump += 1

    if 'Hillary' in title and 'FAKE' in label:
        counter_FClinton += 1

    if 'Hillary' in title and 'REAL' in label:
        counter_TClinton += 1
        
    if 'Republican' in title and 'FAKE' in label:
        counter_FRepublican += 1
    if 'Republican' in title and 'REAL' in label:
        counter_TRepublican += 1
        
    if 'Democrat' in title and 'FAKE' in label:
        counter_FDemocrat += 1
    if 'Democrat' in title and 'REAL' in label:
        counter_TDemocrat += 1
    
    if 'GOP' in title and 'FAKE' in label:
        counter_FGOP += 1
    if 'GOP' in title and 'REAL' in label:
        counter_TGOP += 1

    if 'Obama' in title and 'FAKE' in label:
        counter_FObama += 1
    if 'Obama' in title and 'REAL' in label:
        counter_TObama += 1

# %%
x1 = ['FAKETrump','REALTRUMP', 'FAKEHillary','REALHillary', 'FAKERepublican','REALRepublican','FAKEDemocrat','REALDemocrat','FAKEGOP','REALGOP','FAKEObama','REALObama']
y1 = [counter_FTrump,counter_TTrump,counter_FClinton,counter_TClinton,counter_FRepublican,counter_TRepublican,counter_FDemocrat,counter_TDemocrat,counter_FGOP,counter_TGOP,counter_FObama,counter_TObama]


c = ['red','blue']

        
plt.bar(x1, y1, color=c)
plt.title("Read/Fake news according to a few select keywords")
plt.xlabel("Fake/Real")
plt.ylabel("Number of fakes and reals")
plt.show()

# %%
# Extract data for fake news from a label column
df_fake =df.loc[df['label'] == "FAKE", ['text']]
df_fake['text'] = df_fake['text'].str.lower()
df_fake
# Out:
#                                                    text
# 0     daniel greenfield, a shillman journalism fello...
# 1     google pinterest digg linkedin reddit stumbleu...
# 3     — kaydee king (@kaydeeking) november 9, 2016 t...
# 5     i’m not an immigrant, but my grandparents are....
# 6     share this baylee luciani (left), screenshot o...
# ...                                                 ...
# 6326  doj complaint: comey under fire over partisan ...
# 6328
# 6329  julian assange has claimed the hillary clinton...
# 6331  the ‘p’ in pbs should stand for ‘plutocratic’ ...
# 6332  anti-trump protesters are tools of the oligarc...
#
# [3164 rows x 1 columns]

# %%
# Count word in the text of fake news
df_fake["text_new"] = df_fake['text'].str.lower().str.replace('[^\w\s]','')
new_df_1 = df_fake.text_new.str.split(expand=True).stack().value_counts().reset_index()
new_df_1.columns = ['Word', 'Frequency']
head_df_1 = new_df_1.head(20)
head_df_1
# Out:
# /var/folders/t5/k1q9qhlx32344zdlcz5f9jt40000gn/T/ipykernel_25173/200913577.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_fake["text_new"] = df_fake['text'].str.lower().str.replace('[^\w\s]','')
#     Word  Frequency
# 0    the     129208
# 1     of      60881
# 2     to      59895
# 3    and      54650
# 4      a      42514
# 5     in      40230
# 6   that      29336
# 7     is      27126
# 8    for      19498
# 9     on      15954
# 10    it      15026
# 11    as      14356
# 12  with      13440
# 13  this      12830
# 14   are      12821
# 15    by      12335
# 16    be      11631
# 17   was      11131
# 18  have      10591
# 19   not       9922

# %%
# Make a bar plot for the word frequency in the text of fake news
head_df_1.plot.barh(x="Word", y = "Frequency")
# Out:
# <AxesSubplot:ylabel='Word'>

# %%
# Extract data for real news from a label column
df_real = df.loc[df['label'] == "REAL", ['text']]
df_real['text'] = df_real['text'].str.lower()
df_real
# Out:
#                                                    text
# 2     u.s. secretary of state john f. kerry said mon...
# 4     it's primary day in new york and front-runners...
# 7     a czech stockbroker who saved more than 650 je...
# 8     hillary clinton and donald trump made some ina...
# 9     iranian negotiators reportedly have made a las...
# ...                                                 ...
# 6324  most conservatives who oppose marriage equalit...
# 6327  the freshman senator from georgia quoted scrip...
# 6330  the state department told the republican natio...
# 6333  addis ababa, ethiopia —president obama convene...
# 6334  jeb bush is suddenly attacking trump. here's w...
#
# [3171 rows x 1 columns]

# %%
# Count word in the text of real news
df_real["text_new"] = df_real['text'].str.lower().str.replace('[^\w\s]','')
new_df_2 = df_real.text_new.str.split(expand=True).stack().value_counts().reset_index()
new_df_2.columns = ['Word', 'Frequency']
head_df_2 = new_df_2.head(20)
head_df_2
# Out:
# /var/folders/t5/k1q9qhlx32344zdlcz5f9jt40000gn/T/ipykernel_25173/394062585.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_real["text_new"] = df_real['text'].str.lower().str.replace('[^\w\s]','')
#     Word  Frequency
# 0    the     161113
# 1     to      79359
# 2     of      68684
# 3      a      65342
# 4    and      64583
# 5     in      57781
# 6   that      39996
# 7     is      27208
# 8    for      26790
# 9     on      24640
# 10    he      21341
# 11    as      18142
# 12  with      17389
# 13  said      17187
# 14    it      16773
# 15   his      16062
# 16   was      15956
# 17   but      13652
# 18  have      13635
# 19    at      13319

# %%
# Make a bar plot for the word frequency in the text of real news
head_df_2.plot.barh(x="Word", y = "Frequency")
# Out:
# <AxesSubplot:ylabel='Word'>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report

# %%
vectorizer = TfidfVectorizer()

# %%
x = vectorizer.fit_transform(df['title'])
y = df['label']

# %%
vectorizer.get_feature_names()
# Out:
# ['00',
#  '000',
#  '00pm',
#  '01',
#  '04',
#  '05',
#  '06',
#  '08',
#  '10',
#  '100',
#  '1000',
#  '1000s',
#  '100k',
#  '100m',
#  '100percentfedup',
#  '101',
#  '106',
#  '10k',
#  '11',
#  '116',
#  '117',
#  '11th',
#  '12',
#  '120',
#  '122',
#  '1227',
#  '124th',
#  '125',
#  '126',
#  '12th',
#  '13',
#  '130',
#  '1390',
#  '14',
#  '140',
#  '141',
#  '147',
#  '15',
#  '150',
#  '159',
#  '16',
#  '160',
#  '1612',
#  '16th',
#  '17',
#  '170',
#  '179',
#  '18',
#  '180',
#  '184',
#  '1862',
#  '19',
#  '1940s',
#  '1945',
#  '1946',
#  '1950',
#  '1951',
#  '1960s',
#  '1970',
#  '1980',
#  '1980s',
#  '1984',
#  '199',
#  '1990s',
#  '1992',
#  '1993',
#  '1994',
#  '1996',
#  '1b',
#  '1st',
#  '20',
#  '200',
#  '2000',
#  '2001',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '200m',
#  '200x',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2016ers',
#  '2017',
#  '2018',
#  '202',
#  '2020',
#  '2050',
#  '205m',
#  '207',
#  '20k',
#  '21',
#  '211',
#  '215',
#  '21st',
#  '22',
#  '220',
#  '223',
#  '224',
#  '225',
#  '23',
#  '234',
#  '237',
#  '24',
#  '241',
#  '25',
#  '250',
#  '257k',
#  '26',
#  '27',
#  '270',
#  '271',
#  '275',
#  '28',
#  '2816',
#  '29',
#  '292',
#  '29th',
#  '2nd',
#  '2s',
#  '30',
#  '300',
#  '300k',
#  '30mki',
#  '30th',
#  '31',
#  '31st',
#  '32',
#  '32nd',
#  '33',
#  '34',
#  '340',
#  '342',
#  '35',
#  '353',
#  '36',
#  '37',
#  '370',
#  '38',
#  '385',
#  '390k',
#  '3m',
#  '3rd',
#  '3yo',
#  '40',
#  '400',
#  '401',
#  '40th',
#  '41',
#  '42',
#  '43',
#  '45',
#  '450',
#  '45th',
#  '46',
#  '47',
#  '48',
#  '49',
#  '4th',
#  '50',
#  '500',
#  '500th',
#  '50b',
#  '50th',
#  '52',
#  '53',
#  '54',
#  '544',
#  '55',
#  '58',
#  '5g',
#  '5th',
#  '60',
#  '600',
#  '60g',
#  '61',
#  '612b',
#  '62',
#  '63',
#  '63mln',
#  '65',
#  '650',
#  '650k',
#  '67',
#  '691',
#  '6th',
#  '70',
#  '700',
#  '70th',
#  '71',
#  '72',
#  '74',
#  '74b',
#  '75',
#  '750',
#  '76',
#  '76ers',
#  '78',
#  '780',
#  '783',
#  '7th',
#  '80',
#  '800',
#  '804',
#  '80s',
#  '87',
#  '88',
#  '880k',
#  '8th',
#  '90',
#  '900k',
#  '91',
#  '911',
#  '92',
#  '93',
#  '95',
#  '96',
#  '99',
#  '9th',
#  'aap',
#  'abadi',
#  'abandon',
#  'abandoned',
#  'abandoning',
#  'abandons',
#  'abby',
#  'abc',
#  'abducts',
#  'abdullah',
#  'abedin',
#  'abilities',
#  'ability',
#  'able',
#  'abnormal',
#  'aboard',
#  'abolish',
#  'abolished',
#  'abortion',
#  'about',
#  'above',
#  'abridged',
#  'abroad',
#  'abrogation',
#  'absence',
#  'absentee',
#  'absolutely',
#  'abstains',
#  'absurd',
#  'absurdly',
#  'abu',
#  'abuse',
#  'abused',
#  'abusing',
#  'abyss',
#  'aca',
#  'accept',
#  'acceptable',
#  'accepted',
#  'accepting',
#  'accepts',
#  'access',
#  'accident',
#  'accidental',
#  'accidentally',
#  'accidents',
#  'accomplished',
#  'accomplishment',
#  'accord',
#  'according',
#  'account',
#  'accountability',
#  'accounting',
#  'accounts',
#  'accurate',
#  'accusations',
#  'accuse',
#  'accused',
#  'accuser',
#  'accusers',
#  'accuses',
#  'acela',
#  'acheron',
#  'achievement',
#  'achievements',
#  'ackbar',
#  'acknowledge',
#  'acknowledges',
#  'aclu',
#  'acquiring',
#  'acquisition',
#  'acquittal',
#  'acquitted',
#  'acres',
#  'across',
#  'act',
#  'acted',
#  'acting',
#  'action',
#  'actions',
#  'activation',
#  'active',
#  'activist',
#  'activists',
#  'activities',
#  'activity',
#  'actor',
#  'actual',
#  'actually',
#  'acupuncture',
#  'ad',
#  'adamantly',
#  'adams',
#  'adapt',
#  'add',
#  'added',
#  'adderall',
#  'addicted',
#  'addicting',
#  'addiction',
#  'adding',
#  'address',
#  'addresses',
#  'adds',
#  'adelson',
#  'adequate',
#  'adhd',
#  'adhm',
#  'adjustment',
#  'admin',
#  'administration',
#  'administrator',
#  'administrators',
#  'admirable',
#  'admirals',
#  'admirer',
#  'admit',
#  'admits',
#  'admitted',
#  'admittedly',
#  'admitting',
#  'adoption',
#  'adopts',
#  'adores',
#  'adpres',
#  'ads',
#  'adult',
#  'adults',
#  'advance',
#  'advanced',
#  'advances',
#  'advantage',
#  'advantages',
#  'advert',
#  'advertisement',
#  'advertisers',
#  'adverts',
#  'advice',
#  'advised',
#  'adviser',
#  'advisers',
#  'advises',
#  'advisor',
#  'advisors',
#  'advocate',
#  'advocates',
#  'aerodynamic',
#  'afar',
#  'affair',
#  'affairs',
#  'affect',
#  'affecting',
#  'affects',
#  'affiliate',
#  'affirmative',
#  'affirms',
#  'afford',
#  'affordable',
#  'affront',
#  'afghan',
#  'afghanistan',
#  'afghans',
#  'aficionados',
#  'afraid',
#  'africa',
#  'african',
#  'after',
#  'aftermath',
#  'aftershocks',
#  'ag',
#  'again',
#  'against',
#  'age',
#  'agencies',
#  'agency',
#  'agenda',
#  'agent',
#  'agents',
#  'ages',
#  'aggressive',
#  'aggressively',
#  'aggro',
#  'aging',
#  'agitators',
#  'agnes',
#  'ago',
#  'agony',
#  'agree',
#  'agreed',
#  'agreement',
#  'agrees',
#  'agriculture',
#  'agropoisons',
#  'ahead',
#  'ai',
#  'aid',
#  'aide',
#  'aided',
#  'aides',
#  'aiding',
#  'aids',
#  'aig',
#  'ailes',
#  'aim',
#  'aimed',
#  'aiming',
#  'aims',
#  'ain',
#  'air',
#  'airbnb',
#  'aircraft',
#  'airman',
#  'airplane',
#  'airport',
#  'airstrike',
#  'airstrikes',
#  'akbar',
#  'al',
#  'alabama',
#  'alarm',
#  'alarmed',
#  'alarming',
#  'alarmists',
#  'alarms',
#  'alasdair',
#  'alaska',
#  'albert',
#  'alberto',
#  'albright',
#  'album',
#  'alcohol',
#  'aleppo',
#  'alert',
#  'alex',
#  'ali',
#  'alicia',
#  'alien',
#  'alienate',
#  'alienating',
#  'alienation',
#  'aliens',
#  'align',
#  'aligning',
#  'alignment',
#  'alito',
#  'alive',
#  'all',
#  'allah',
#  'allahu',
#  'allay',
#  'allegation',
#  'allegations',
#  'alleged',
#  'allegiance',
#  'allen',
#  'alliance',
#  'alliances',
#  'allies',
#  'allocate',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'ally',
#  'almost',
#  'alone',
#  'along',
#  'aloof',
#  'alphabet',
#  'already',
#  'also',
#  'alt',
#  'altered',
#  'altering',
#  'alternate',
#  'alternative',
#  'alternatives',
#  'altruistic',
#  'always',
#  'am',
#  'amazing',
#  'ambassador',
#  'ambition',
#  'ambivalence',
#  'ambulance',
#  'ambush',
#  'ambushed',
#  'ame',
#  'amend',
#  'amendment',
#  'america',
#  'american',
#  'americana',
#  'americanism',
#  'americans',
#  'americas',
#  'amid',
#  'amish',
#  'ammo',
#  'ammon',
#  'ammosexuals',
#  'amnesty',
#  'among',
#  'amount',
#  'amounts',
#  'amp',
#  'amphibious',
#  'amtrak',
#  'amur',
#  'amurexit',
#  'amusing',
#  'amy',
#  'an',
#  'anaheim',
#  'analysis',
#  'analyst',
#  'analysts',
#  'anarchists',
#  'anarchy',
#  'anastasia',
#  'anatomy',
#  'anbar',
#  'anchor',
#  'anchors',
#  'ancient',
#  'ancients',
#  'and',
#  'anderson',
#  'andes',
#  'andrew',
#  'anew',
#  'angel',
#  'angela',
#  'angeles',
#  'angelina',
#  'angels',
#  'anger',
#  'anglin',
#  'angriest',
#  'angry',
#  'animal',
#  'animals',
#  'animosity',
#  'ankle',
#  'ann',
#  'anna',
#  'annihilation',
#  'anniversary',
#  'annotated',
#  'announce',
#  'announced',
#  'announcement',
#  'announces',
#  'announcing',
#  'annual',
#  'annually',
#  'annulment',
#  'anonymous',
#  'anonymously',
#  'another',
#  'anots',
#  'answer',
#  'answered',
#  'answering',
#  'answers',
#  'antarctic',
#  'antarctica',
#  'ante',
#  'anthem',
#  'anthony',
#  'anthropecene',
#  'anti',
#  'antiaircraft',
#  'antibiotic',
#  'anticipated',
#  'anticipates',
#  'anticipation',
#  'antics',
#  'antidepressant',
#  'antiparticle',
#  'antiquities',
#  'antithetical',
#  'antonin',
#  'antonio',
#  'anxiety',
#  'anxious',
#  'anxiously',
#  'any',
#  'anybody',
#  'anymore',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'aos',
#  'ap',
#  'apart',
#  'apartheid',
#  'api',
#  'apocalypse',
#  'apocalyptic',
#  'apologising',
#  'apologist',
#  'apologize',
#  'apologizes',
#  'apologizing',
#  'apology',
#  'apostate',
#  'app',
#  'appalled',
#  'apparent',
#  'appeal',
#  'appeals',
#  'appear',
#  'appearance',
#  'appearances',
#  'appearing',
#  'appears',
#  'appease',
#  'apple',
#  'applebee',
#  'apples',
#  'applications',
#  'applies',
#  'appoint',
#  'appointed',
#  'appointment',
#  'appointments',
#  'appoints',
#  'appreciation',
#  'apprentice',
#  'approach',
#  'approaches',
#  'approaching',
#  'appropriation',
#  'approval',
#  'approve',
#  'approved',
#  'approves',
#  'april',
#  'aqutru',
#  'arab',
#  'arabia',
#  'arabian',
#  'arabic',
#  'arc',
#  'archil',
#  'architect',
#  'arctic',
#  'arcturian',
#  'are',
#  'area',
#  'areas',
#  'aren',
#  'aretha',
#  'argues',
#  'argument',
#  'arguments',
#  'ari',
#  'arianna',
#  'arias',
#  'ariel',
#  'arise',
#  'aristocracy',
#  'arizona',
#  'ark',
#  'arkansas',
#  'arm',
#  'armed',
#  'armenia',
#  'armenians',
#  'arming',
#  'arms',
#  'armstrong',
#  'army',
#  'arnab',
#  'arne',
#  'around',
#  'arquette',
#  'arranged',
#  'arrangements',
#  'arrest',
#  'arrested',
#  'arrests',
#  'arrival',
#  'arrivals',
#  'arrive',
#  'arrives',
#  'arrogance',
#  'arse',
#  'arsenal',
#  'arson',
#  'art',
#  'arteries',
#  'article',
#  'artifact',
#  'artifacts',
#  'artificial',
#  'artist',
#  'aryan',
#  'as',
#  'ascended',
#  'ascends',
#  'asda',
#  'ashton',
#  'ashutosh',
#  'asia',
#  'aside',
#  'ask',
#  'asked',
#  'asking',
#  'asks',
#  'aspartame',
#  'ass',
#  'assad',
#  'assange',
#  'assasination',
#  'assassinate',
#  'assassinated',
#  'assassinating',
#  'assassination',
#  'assassins',
#  'assault',
#  'assaulting',
#  'assembly',
#  'assertion',
#  'assessments',
#  'asset',
#  'assets',
#  'assistance',
#  'assistant',
#  'assisted',
#  'associated',
#  'association',
#  'assume',
#  'assumed',
#  'assumptions',
#  'assures',
#  'asthm',
#  'astonishing',
#  'astronaut',
#  'astronomers',
#  'asylum',
#  'at',
#  'atf',
#  'atlanta',
#  'atlantis',
#  'atm',
#  'atrocities',
#  'att',
#  'attachment',
#  'attack',
#  'attacked',
#  'attackers',
#  'attacking',
#  'attacks',
#  'attempt',
#  'attempted',
#  'attempts',
#  'attend',
#  'attendant',
#  'attendee',
#  'attendees',
#  'attention',
#  'attire',
#  'attitude',
#  'attitudes',
#  'attorney',
#  'attracted',
#  'audacious',
#  'audience',
#  'audio',
#  'auditors',
#  'aumf',
#  'aussie',
#  'australia',
#  'australian',
#  'austria',
#  'austrian',
#  'austyn',
#  'authentic',
#  'author',
#  'authoritarian',
#  'authorities',
#  'authority',
#  'authorization',
#  'authorize',
#  'authorized',
#  'authorizes',
#  'autism',
#  'autistic',
#  'auto',
#  'automatically',
#  'automation',
#  'autonomous',
#  'available',
#  'avenging',
#  'average',
#  'avert',
#  'averted',
#  'aviv',
#  'avocado',
#  'avoid',
#  'avoided',
#  'avoids',
#  'await',
#  'awaited',
#  'awaits',
#  'awakening',
#  'award',
#  'awards',
#  'away',
#  'awe',
#  'awesome',
#  'awful',
#  'awkward',
#  'awkwardly',
#  'awol',
#  'axelrod',
#  'axis',
#  'ayahuasca',
#  'ayatollah',
#  'ayotte',
#  'az',
#  'baba',
#  'babies',
#  'baby',
#  'babylon',
#  'back',
#  'backbone',
#  'backed',
#  'backer',
#  'backers',
#  'backfire',
#  'backfires',
#  'background',
#  'backing',
#  'backlash',
#  'backlog',
#  'backs',
#  'backseat',
#  'backstory',
#  'backup',
#  'backward',
#  'bacon',
#  'bad',
#  'badass',
#  'badassery',
#  'bader',
#  'badges',
#  'badham',
#  'badly',
#  'baffled',
#  'baffles',
#  'baffling',
#  'baghdad',
#  'bags',
#  'bahaha',
#  'bahraini',
#  'baier',
#  'bail',
#  'bakery',
#  'baking',
#  'balance',
#  'balanced',
#  'balancing',
#  'bald',
#  'baldwins',
#  'balfour',
#  'balkans',
#  'ball',
#  'ballistic',
#  'balloo',
#  'ballot',
#  'balloting',
#  'ballots',
#  'balls',
#  'balochistan',
#  'baltic',
#  'baltimore',
#  'ban',
#  'banana',
#  'bancroft',
#  'bang',
#  'banging',
#  'banished',
#  'bank',
#  'banker',
#  'bankers',
#  'banking',
#  'bankrupt',
#  'banks',
#  'banned',
#  'banner',
#  'banners',
#  'bannon',
#  'bans',
#  'bar',
#  'barack',
#  'barage',
#  'barbara',
#  'barbarians',
#  'barbaric',
#  'barely',
#  'bargain',
#  'baristas',
#  'barney',
#  'barnstorm',
#  'baron',
#  'barrage',
#  'barrel',
#  'barrier',
#  'barriers',
#  'barter',
#  'base',
#  'baseball',
#  'based',
#  'basement',
#  'bases',
#  'bash',
#  'bashar',
#  'bashing',
#  'basically',
#  'basil',
#  'basis',
#  'basket',
#  'batch',
#  'bathroom',
#  'bathrooms',
#  'baton',
#  'batteries',
#  'battery',
#  'battle',
#  'battleground',
#  'battles',
#  'battleship',
#  'battling',
#  'bauer',
#  'bay',
#  'bayh',
#  'baylor',
#  'bbc',
#  'be',
#  'beammeupscotty',
#  'beans',
#  'bears',
#  'beast',
#  'beat',
#  'beaten',
#  'beating',
#  'beats',
#  'beau',
#  'beaulieu',
#  'beautiful',
#  'beauty',
#  'became',
#  'because',
#  'beck',
#  'beckel',
#  'become',
#  'becomes',
#  'becoming',
#  'bee',
#  'beef',
#  'beeley',
#  'been',
#  'beer',
#  'beers',
#  'before',
#  'began',
#  'begging',
#  'begin',
#  'beginning',
#  ...]

# %%
def guess(label):
    if label == 'FAKE':
        return 1
    return 0

# %%
def plot_point(guesses, answers):
    for i in range(0, len(guesses), 20):
        g = guess(guesses[i])
        if guesses[i] == answers[i]:
            plt.plot(i, g, 'go')
        else:
            plt.plot(i, g, 'ro')
    plt.show()

# %%
kf = KFold(5)
for train, test in kf.split(x):
    print(train, test)
    model = SVC()
    model.fit(x[train], y.iloc[train])
    guesses = model.predict(x[test])
    answers = y.iloc[test].to_numpy()
    plot_point(guesses, answers)
    print(classification_report(answers, guesses))
    print('Score', model.score(x[test], y.iloc[test]))
# Out:
# [1267 1268 1269 ... 6332 6333 6334] [   0    1    2 ... 1264 1265 1266]
#               precision    recall  f1-score   support
#
#         FAKE       0.81      0.88      0.85       634
#         REAL       0.87      0.79      0.83       633
#
#     accuracy                           0.84      1267
#    macro avg       0.84      0.84      0.84      1267
# weighted avg       0.84      0.84      0.84      1267
#
# Score 0.8382004735595896
# [   0    1    2 ... 6332 6333 6334] [1267 1268 1269 ... 2531 2532 2533]
#               precision    recall  f1-score   support
#
#         FAKE       0.81      0.86      0.83       663
#         REAL       0.84      0.77      0.80       604
#
#     accuracy                           0.82      1267
#    macro avg       0.82      0.82      0.82      1267
# weighted avg       0.82      0.82      0.82      1267
#
# Score 0.8208366219415943
# [   0    1    2 ... 6332 6333 6334] [2534 2535 2536 ... 3798 3799 3800]
#               precision    recall  f1-score   support
#
#         FAKE       0.78      0.87      0.82       595
#         REAL       0.87      0.79      0.83       672
#
#     accuracy                           0.83      1267
#    macro avg       0.83      0.83      0.83      1267
# weighted avg       0.83      0.83      0.83      1267
#
# Score 0.8255722178374112
# [   0    1    2 ... 6332 6333 6334] [3801 3802 3803 ... 5065 5066 5067]
#               precision    recall  f1-score   support
#
#         FAKE       0.80      0.86      0.83       628
#         REAL       0.85      0.79      0.82       639
#
#     accuracy                           0.82      1267
#    macro avg       0.83      0.82      0.82      1267
# weighted avg       0.83      0.82      0.82      1267
#
# Score 0.823993685872139
# [   0    1    2 ... 5065 5066 5067] [5068 5069 5070 ... 6332 6333 6334]
#               precision    recall  f1-score   support
#
#         FAKE       0.80      0.86      0.83       644
#         REAL       0.84      0.78      0.81       623
#
#     accuracy                           0.82      1267
#    macro avg       0.82      0.82      0.82      1267
# weighted avg       0.82      0.82      0.82      1267
#
# Score 0.8184688239936859
